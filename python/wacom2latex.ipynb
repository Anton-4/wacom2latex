# 40  0.814815  0.481481  0.833333  0.481481  0.833333  0.481481  0.833333
# 41  0.678571  0.857143  0.696429  0.875000  0.696429  0.892857  0.696429
# 42  0.793103  0.706897  0.810345  0.724138  0.810345  0.741379  0.775862
# 43  0.634921  0.539683  0.650794  0.539683  0.650794  0.539683  0.666667
# 44  0.870370  0.500000  0.888889  0.500000  0.907407  0.481481  0.907407
# 45  0.927273  0.418182  0.945455  0.418182  0.927273  0.418182  0.890909
# 46  0.881356  0.389831  0.898305  0.389831  0.898305  0.389831  0.898305
# 47  0.683333  0.483333  0.700000  0.483333  0.733333  0.450000  0.750000
# 48  0.912281  0.438596  0.929825  0.421053  0.929825  0.421053  0.912281
# 49  0.910714  0.410714  0.928571  0.410714  0.928571  0.410714  0.928571
# 50  0.923077  0.500000  0.923077  0.500000  0.923077  0.500000  0.923077
# 51  0.672727  0.763636  0.672727  0.763636  0.672727  0.763636  0.672727
# 52  0.666667  0.530303  0.681818  0.530303  0.681818  0.530303  0.681818
# 53  0.687500  0.531250  0.687500  0.531250  0.687500  0.531250  0.703125
# 54  0.783333  0.250000  0.800000  0.266667  0.816667  0.266667  0.833333
# 55  0.907407  0.333333  0.944444  0.333333  0.944444  0.333333  0.907407
# 56  0.849057  0.547170  0.867925  0.547170  0.886792  0.547170  0.886792
# 57  0.553846  0.538462  0.584615  0.538462  0.584615  0.538462  0.600000
# 58  0.875000  0.357143  0.892857  0.357143  0.875000  0.375000  0.875000
# 59  0.948276  0.275862  0.948276  0.275862  0.931034  0.275862  0.913793
#
#            7         8         9  ...          55        56        57  \
# 0   0.446429  0.839286  0.482143  ...    0.000000  0.000000  0.000000
# 1   0.849057  0.754717  0.830189  ...    0.000000  0.000000  0.000000
# 2   0.671875  0.593750  0.625000  ...    0.000000  0.000000  0.000000
# 3   0.607843  0.823529  0.568627  ...    0.000000  0.000000  0.000000
# 4   0.433962  0.886792  0.433962  ...    0.000000  0.000000  0.000000
# 5   0.444444  0.981481  0.425926  ...    0.962963  0.759259  1.000000
# 6   0.474576  0.813559  0.474576  ...    0.779661  0.694915  0.796610
# 7   0.625000  0.732143  0.607143  ...    0.000000  0.000000  0.000000
# 8   0.370968  0.838710  0.419355  ...    0.483871  0.935484  0.435484
# 9   0.388889  0.925926  0.388889  ...    0.962963  0.907407  0.981481
# 10  0.480000  0.900000  0.480000  ...    0.000000  0.000000  0.000000
# 11  0.962963  0.666667  0.981481  ...    0.870370  0.814815  0.944444
# 12  0.679245  0.792453  0.660377  ...    0.000000  0.000000  0.000000
# 13  0.568966  0.741379  0.568966  ...    1.000000  0.793103  1.000000
# 14  0.137931  0.844828  0.137931  ...    0.000000  0.000000  0.000000
# 15  0.585714  0.742857  0.585714  ...    0.000000  0.000000  0.000000
# 16  0.672727  0.981818  0.545455  ...    0.000000  0.000000  0.000000
# 17  0.686567  0.537313  0.686567  ...    0.000000  0.000000  0.000000
# 18  0.551724  0.758621  0.620690  ...    0.517241  0.913793  0.534483
# 19  0.379310  0.965517  0.379310  ...    0.000000  0.000000  0.000000
# 20  0.473684  0.807018  0.508772  ...    0.000000  0.000000  0.000000
# 21  0.964912  0.561404  0.964912  ...    1.000000  0.719298  1.000000
# 22  0.683333  0.700000  0.683333  ...    0.000000  0.000000  0.000000
# 23  0.603175  0.682540  0.603175  ...    0.000000  0.000000  0.000000
# 24  0.470588  0.882353  0.470588  ...    0.862745  1.000000  0.882353
# 25  0.296296  0.777778  0.351852  ...    0.000000  0.000000  0.000000
# 26  0.420000  0.920000  0.420000  ...    0.000000  0.000000  0.000000
# 27  0.549020  0.666667  0.509804  ...    0.980392  0.745098  1.000000
# 28  0.357143  0.803571  0.446429  ...    0.000000  0.000000  0.000000
# 29  0.482143  0.857143  0.482143  ...    0.000000  0.000000  0.000000
# 30  0.471698  0.830189  0.471698  ...    0.000000  0.000000  0.000000
# 31  0.859649  0.649123  0.842105  ...    0.000000  0.000000  0.000000
# 32  0.656250  0.625000  0.640625  ...    0.968750  0.671875  0.984375
# 33  0.603448  0.672414  0.603448  ...    0.000000  0.000000  0.000000
# 34  0.547170  0.849057  0.584906  ...    0.000000  0.000000  0.000000
# 35  0.392857  0.875000  0.392857  ...    0.857143  0.857143  0.857143
# 36  0.482143  0.785714  0.553571  ...    0.000000  0.000000  0.000000
# 37  0.590164  0.639344  0.573770  ...    0.967213  0.622951  0.983607
# 38  0.403509  0.877193  0.421053  ...    0.578947  0.964912  0.508772
# 39  0.350877  0.877193  0.350877  ...    0.000000  0.000000  0.000000
# 40  0.481481  0.833333  0.481481  ...    0.000000  0.000000  0.000000
# 41  0.892857  0.732143  0.839286  ...    0.000000  0.000000  0.000000
# 42  0.758621  0.741379  0.775862  ...    0.000000  0.000000  0.000000
# 43  0.523810  0.682540  0.507937  ...    0.952381  0.730159  0.984127
# 44  0.481481  0.907407  0.481481  ...    0.000000  0.000000  0.000000
# 45  0.400000  0.836364  0.400000  ...    0.000000  0.000000  0.000000
# 46  0.389831  0.864407  0.406780  ...    0.000000  0.000000  0.000000
# 47  0.433333  0.783333  0.433333  ...    0.000000  0.000000  0.000000
# 48  0.438596  0.859649  0.491228  ...    0.403509  0.947368  0.421053
# 49  0.410714  0.928571  0.392857  ...    0.875000  0.928571  0.964286
# 50  0.500000  0.923077  0.519231  ...    0.000000  0.000000  0.000000
# 51  0.781818  0.672727  0.781818  ...    0.000000  0.000000  0.000000
# 52  0.530303  0.666667  0.500000  ...    1.000000  0.772727  1.000000
# 53  0.531250  0.718750  0.515625  ...    1.000000  0.703125  1.000000
# 54  0.283333  0.833333  0.283333  ...    0.566667  0.983333  0.566667
# 55  0.333333  0.870370  0.333333  ...    0.981481  0.000000  0.000000
# 56  0.547170  0.867925  0.547170  ...    0.000000  0.000000  0.000000
# 57  0.523077  0.615385  0.507692  ...    0.969231  0.615385  1.000000
# 58  0.392857  0.875000  0.392857  ...    0.000000  0.000000  0.000000
# 59  0.293103  0.879310  0.327586  ...    0.000000  0.000000  0.000000
#
#           58        59        60        61        62        63  label
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      1
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      2
# 3   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      3
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      4
# 5   0.759259  1.000000  0.777778  0.944444  0.000000  0.000000      5
# 6   0.677966  0.796610  0.000000  0.000000  0.000000  0.000000      6
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      7
# 8   0.935484  0.419355  0.935484  0.419355  0.935484  0.403226      8
# 9   0.870370  1.000000  0.833333  0.962963  0.814815  0.907407      9
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 11  0.814815  0.981481  0.814815  1.000000  0.814815  0.981481      1
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      2
# 13  0.793103  1.000000  0.810345  0.931034  0.000000  0.000000      3
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      4
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      5
# 16  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      6
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      7
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      8
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      9
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 21  0.719298  1.000000  0.719298  0.982456  0.719298  0.964912      1
# 22  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      2
# 23  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      3
# 24  1.000000  0.901961  0.980392  0.921569  0.000000  0.000000      4
# 25  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      5
# 26  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      6
# 27  0.745098  1.000000  0.000000  0.000000  0.000000  0.000000      7
# 28  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      8
# 29  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      9
# 30  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 31  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      1
# 32  0.687500  0.984375  0.703125  0.984375  0.718750  1.000000      2
# 33  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      3
# 34  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      4
# 35  0.857143  0.839286  0.000000  0.000000  0.000000  0.000000      5
# 36  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      6
# 37  0.606557  1.000000  0.000000  0.000000  0.000000  0.000000      7
# 38  0.982456  0.473684  0.947368  0.491228  0.000000  0.000000      8
# 39  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      9
# 40  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 41  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      1
# 42  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      2
# 43  0.714286  1.000000  0.714286  1.000000  0.714286  0.984127      3
# 44  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      4
# 45  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      5
# 46  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      6
# 47  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      7
# 48  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      8
# 49  0.910714  1.000000  0.892857  1.000000  0.892857  0.964286      9
# 50  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      0
# 51  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      1
# 52  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      2
# 53  0.718750  0.968750  0.750000  0.937500  0.000000  0.000000      3
# 54  1.000000  0.583333  0.983333  0.600000  0.000000  0.000000      4
# 55  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      5
# 56  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      6
# 57  0.615385  1.000000  0.600000  1.000000  0.000000  0.000000      7
# 58  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      8
# 59  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000      9
#
# [60 rows x 65 columns]

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split


train, test = train_test_split(df, test_size = 0.2)

x_train = train.iloc[:,:-1].as_matrix()
y_train = train[['label']].values.flatten()

x_test = test.iloc[:,:-1].as_matrix()
y_test = test[['label']].values.flatten()

batch_size = 128
num_classes = 10
epochs = 3
input_size = 64

y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

model = Sequential()
model.add(Dense(64, activation='relu', input_dim= input_size))
model.add(Dense(32, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0),
              metrics=['accuracy'])

model.fit(x_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      verbose=1,
      validation_data=(x_test, y_test))

score = model.evaluate(x_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Train on 48 samples, validate on 12 samples
# Epoch 1/3
# 48/48 [==============================] - 0s - loss: 2.3418 - acc: 0.1042 - val_loss: 2.2278 - val_acc: 0.0833
# Epoch 2/3
# 48/48 [==============================] - 0s - loss: 2.3074 - acc: 0.1667 - val_loss: 2.2203 - val_acc: 0.1667
# Epoch 3/3
# 48/48 [==============================] - 0s - loss: 2.2804 - acc: 0.1458 - val_loss: 2.2186 - val_acc: 0.1667
# Test loss: 2.21861863136
# Test accuracy: 0.166666671634

# %%
# convert class vectors to binary class matrices


#model = Sequential()
#model.add(Conv2D(32, kernel_size=(3, 3),
#                 activation='relu',
#                 input_shape=input_shape))
#model.add(Conv2D(64, (3, 3), activation='relu'))
#model.add(MaxPooling2D(pool_size=(2, 2)))
#model.add(Dropout(0.25))
#model.add(Flatten())
#model.add(Dense(128, activation='relu'))
#model.add(Dropout(0.5))
#model.add(Dense(num_classes, activation='softmax'))

#model.compile(loss=keras.losses.categorical_crossentropy,
#              optimizer=keras.optimizers.Adadelta(),
#              metrics=['accuracy'])

#model.fit(x_train, y_train,
#          batch_size=batch_size,
#          epochs=epochs,
#          verbose=1,
#          validation_data=(x_test, y_test))
#score = model.evaluate(x_test, y_test, verbose=0)
#print('Test loss:', score[0])
#print('Test accuracy:', score[1])
# Out:
# Using TensorFlow backend.
# x_train shape: (60000, 28, 28, 1)
# 60000 train samples
# 10000 test samples
